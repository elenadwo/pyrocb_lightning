# %%
import os
import numpy as np 
import xarray
import pandas as pd

# %%
os.system("nohup python clean4_merra.py")
# Out:
# 0

# %%
# clean1_bcaod550 = pd.read_csv('/data2/edworak/data/cams_lightning_omaod550_clean4.csv')
# clean1_bcaod550
pd.read_csv("/data2/edworak/data/merra_lightning_OCCMASS_clean4.csv")
# Out:
#       Unnamed: 0  year  month  day  hour  minute     second  aod_lat  \
# 0              0  2019      6   27    20      50   3.478660  53.1479
# 1              1  2019      6   27    20      50   3.488611  53.1684
# 2              2  2019      6   27    20      50   3.491337  53.1469
# 3              3  2019      6   27    20      50   3.546841  53.1405
# 4              4  2019      6   27    20      50   4.308935  52.6089
# ...          ...   ...    ...  ...   ...     ...        ...      ...
# 1676         569  2019      6   28     0      38   8.525068  53.9218
# 1677         570  2019      6   28     0      39  14.909820  53.5473
# 1678         571  2019      6   28     0      39  14.911943  53.5450
# 1679         572  2019      6   28     0      39  32.694911  53.8526
# 1680         573  2019      6   28     0      39  32.694911  53.8526
#
#        aod_lon  peak current C or G    CMI_C14       tlat        tlon  \
# ...
