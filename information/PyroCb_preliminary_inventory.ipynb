# %%
import pandas as pd
df = pd.read_csv('PyroCb_preliminary_inventory_2019-2020_v3.csv')
df

#for only the latitudes: 
#df["Lat"]

# to see exactly what variable names are 
#df.columns

#df["Estimated pyroCb injection duration (hh:mm) "]
# Out:
#     PyroCb Event date and start time  Multi-pulse pyroCb? 0 = no, 1 = yes   \
# 0                2019-01-25 02:20:00                                     1
# 1                2019-02-03 03:30:00                                     0
# 2                2019-02-03 07:00:00                                     0
# 3                2019-02-27 06:00:00                                     0
# 4                2019-02-27 06:00:00                                     1
# ..                               ...                                   ...
# 128              2020-09-09 10:10:00                                     1
# 129              2020-09-19 19:00:00                                     1
# 130              2020-10-06 18:45:00                                     0
# 131              2020-10-22 00:00:00                                     1
# 132              2020-10-22 18:15:00                                     1
#
#     Estimated pyroCb injection duration (hh:mm)   \
# ...
