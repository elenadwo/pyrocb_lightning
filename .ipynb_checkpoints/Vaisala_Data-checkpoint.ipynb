# %% [markdown]
# ## trying to work with vaisala data
# - file name is "/data/edworak/E_Dworak_ltg 2.txt"

# %%
import pandas as pd
import numpy as np
import os
import fileinput
import time

import subprocess
import geopandas
import pandas

# %% [markdown]
# use filezilla to load in data

# %% [markdown]
# - load in data to save to format within file that is easy to read
# - load in save as binary file (matlab is binary file), then load that file
# - can load in only what I want within the for loop
# - can read in file at once at start, or load it in like this then save it as usable format

# %% [markdown]
# https://www.geeksforgeeks.org/how-to-read-large-text-files-in-python/

# %%
# works to read in the file i have in jupyter already 

#time at the start of program is noted
start = time.time()
  
#keeps a track of number of lines in the file
# doesnt load entire file into memory
# data in contained in lines, could select lines you want by date and save to data frame
count = 0
lightning = []
date = []
Time = []
Lat = []
Lon = []
Peak_Cur = []
C_CG = []

for lines in fileinput.input(['/data/edworak/E_Dworak_ltg 2.txt']):
    print(lines)
    lightning.append(lines)
    date.append(lines[0:10])
    count = count + 1
    #if count > 10: 
        #break 
#time at the end of program execution is noted
end = time.time()
# must close file so file reader closes and you can run it again 
fileinput.close()
  
#total time taken to print the file
print("Execution time in seconds: ",(end - start))
print("No. of lines printed: ",count)


# may still run into the issue that it cant print everything out
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
with open('/data/edworak/E_Dworak_ltg 2.txt') as infile:
    for line in infile:
        print(line)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### read specific part of large file in python
# You can seek into the file the file and then read a certain amount from there. Seek allows you to get to a specific offset within a file, and then you can limit your read to only the number of bytes in that range.
#
# with open(filename) as fin: <br>
#     fin.seek(start_index) <br>
#     data = fin.read(end_index - start_index)
#
# Syntax: f.seek(offset, from_what), where f is file pointer <br>
# Parameters: <br>
# Offset: Number of positions to move forward <br>
# from_what: It defines point of reference.<br>
# Returns: Return the new absolute position.<br>

# %%
# 136 for header 
# 54 per line 
# start index of june 29 2021: 136 + (54 * 5305660)

start_index = 136 + (54 * 5305660)
end_index = 136 + (54 * 5350000)

with open('/data/edworak/E_Dworak_ltg 2.txt') as infile:
    infile.seek(start_index)
    data = infile.read(end_index - start_index)
    print(data)
# Out:
# 2021-06-29 00:00:01.113  57.7867 -123.3619    +6.7  C
# 2021-06-29 00:00:14.823  57.9867 -122.3275    +5.5  C
# 2021-06-29 00:00:25.591  58.0317 -122.3642    +7.1  C
# 2021-06-29 00:00:25.599  58.0018 -122.3158    -5.8  G
# 2021-06-29 00:00:25.619  58.0054 -122.3243    -4.6  C
# 2021-06-29 00:00:40.133  58.0143 -122.3548    +3.2  C
# 2021-06-29 00:00:44.494  57.7630 -122.3292    +3.6  C
# 2021-06-29 00:01:03.572  58.0412 -122.3041    +3.2  C
# 2021-06-29 00:01:23.637  58.0136 -122.2343    +3.6  C
# 2021-06-29 00:01:23.795  58.0162 -122.2462    -7.3  G
# 2021-06-29 00:01:23.816  58.0327 -122.3253   -11.7  C
# 2021-06-29 00:01:23.821  58.0130 -122.2683   +11.0  C
# 2021-06-29 00:01:27.846  58.0465 -122.3070    +4.4  C
# 2021-06-29 00:01:34.411  58.0514 -122.2654   +30.2  C
# 2021-06-29 00:01:35.714  58.0202 -122.3004    +7.6  G
# 2021-06-29 00:01:35.970  57.9892 -122.1656    +6.6  C
# 2021-06-29 00:01:56.009  57.7571 -122.3491    +3.4  C
# ...

# %% [markdown]
# ### using geopandas
# geopandas.read_file
# geopandas.read_file(filename, bbox=None, mask=None, rows=None, engine=None, **kwargs)¶

# %%
df = txtfile.read_file("/data/edworak/E_Dworak_ltg 2.txt", rows=10, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df = txtfile.read_file("/data/edworak/E_Dworak_ltg 2.txt", rows=10, encoding='utf-8')
#
# NameError: name 'txtfile' is not defined

# %% [markdown]
# ## pandas read csv
# data=pandas.read_csv(‘filename.txt’, sep=’ ‘, header=None, names=[“Column1”, “Column2”])

# %%
data = pandas.read_csv("/data/edworak/E_Dworak_ltg 2.txt",  header=None, sep = " ", names=["Date", "Time", "Lat", "Lon", "Peak_Cur", "C_CG"], low_memory=False)
data
